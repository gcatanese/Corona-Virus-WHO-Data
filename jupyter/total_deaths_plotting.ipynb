# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
filename = '../data/csv/total_deaths.csv'
df = pd.read_csv(filename)

# %%
d_from = '2020-02-28'
d_to = '2020-03-31'

df = df[(df['date'] >= d_from) & (df['date'] <= d_to)]
df['date'] = pd.to_datetime(df['date'])

# %%
all_data = df[['date', 'Italy', 'United Kingdom', 'Netherlands', 'Spain']]
all_data.head
# Out:
# <bound method NDFrame.head of          date  Italy  United Kingdom  Netherlands  Spain
# 59 2020-02-28     17               0            0      0
# 60 2020-02-29     21               0            0      0
# 61 2020-03-01     29               0            0      0
# 62 2020-03-02     35               0            0      0
# 63 2020-03-03     52               0            0      0
# 64 2020-03-04     80               0            0      0
# 65 2020-03-05    107               0            0      1
# 66 2020-03-06    148               1            0      3
# 67 2020-03-07    197               1            1      5
# 68 2020-03-08    233               2            1      5
# 69 2020-03-09    366               3            3      5
# 70 2020-03-10    464               5            3     28
# 71 2020-03-11    631               6            4     35
# 72 2020-03-12    827               6            5     47
# 73 2020-03-13   1016              10            5     84
# 74 2020-03-14   1268              10            5    121
# 75 2020-03-15   1441              21           12    136
# 76 2020-03-16   1811              35           20    288
# 77 2020-03-17   2158              55           24    309
# 78 2020-03-18   2505              60           24    491
# 79 2020-03-19   2978             103           58    598
# 80 2020-03-20   3407             144           76    767
# 81 2020-03-21   4032             177          106   1002
# 82 2020-03-22   4827             233          136   1326
# 83 2020-03-23   5476             281          179   1720
# 84 2020-03-24   6077             335          213   2182
# 85 2020-03-25   6820             422          276   2696
# 86 2020-03-26   7505             422          356   3434>

# %%
import datetime

plt.rcParams.update({'font.size': 16})
plt.rcParams['axes.facecolor'] = 'whitesmoke'

ax = all_data.plot(figsize=(20,10), x='date', color=('b','r','orange','g'))


plt.axvline(x= datetime.datetime(2020, 3, 9, 0, 0), color = 'b')  # IT lockdown
plt.axvline(x= datetime.datetime(2020, 3, 21, 0, 0), color = 'r') # UK lockdown
plt.axvline(x= datetime.datetime(2020, 3, 16, 0, 0), color = 'orange') # NL lockdown
plt.axvline(x= datetime.datetime(2020, 3, 14, 0, 0), color = 'g') # ES lockdown
plt.legend()

left, width = .05, .5
bottom, height = .70, .5
right = left + width
top = bottom + height

ax.xaxis.set_major_locator(MultipleLocator(1))


ax.text(.26, .70, 'Italy Lockdown',
        horizontalalignment='left',
        verticalalignment='bottom',
        transform=ax.transAxes)

ax.text(.62, .70, 'NL Lockdown',
        horizontalalignment='left',
        verticalalignment='bottom',
        transform=ax.transAxes)

ax.text(.68, .80, 'UK Lockdown',
        horizontalalignment='left',
        verticalalignment='bottom',
        transform=ax.transAxes)

ax.text(.44, .80, 'ES Lockdown',
        horizontalalignment='left',
        verticalalignment='bottom',
        transform=ax.transAxes)

plt.show()
