# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
filename = '../data/csv/total_cases.csv'
df = pd.read_csv(filename)

# %%
d_from = '2020-03-01'
d_to = '2020-04-11'

df = df[(df['date'] >= d_from) & (df['date'] <= d_to)]
df['date'] = pd.to_datetime(df['date'])

# %%
all_data = df[['date', 'Italy', 'United Kingdom', 'Netherlands', 'Spain']]
all_data.head
# Out:
# <bound method NDFrame.head of           date   Italy  United Kingdom  Netherlands   Spain
# 61  2020-03-01    1128              23            7      66
# 62  2020-03-02    1689              36           13      83
# 63  2020-03-03    2036              40           18     114
# 64  2020-03-04    2502              51           28     151
# 65  2020-03-05    3089              85           38     200
# 66  2020-03-06    3858             115           82     261
# 67  2020-03-07    4636             163          128     374
# 68  2020-03-08    5883             206          188     430
# 69  2020-03-09    7375             273          265     589
# 70  2020-03-10    9172             321          321    1204
# 71  2020-03-11   10149             373          382    1639
# 72  2020-03-12   12462             456          503    2140
# 73  2020-03-13   15113             590          614    3004
# 74  2020-03-14   17660             707          804    4231
# 75  2020-03-15   21157            1140          959    5753
# 76  2020-03-16   23980            1391         1135    7753
# 77  2020-03-17   27980            1543         1413    9191
# 78  2020-03-18   31506            1950         1705   11178
# 79  2020-03-19   35713            2630         2051   13716
# 80  2020-03-20   41035            3277         2460   17147
# 81  2020-03-21   47021            3983         2994   19980
# 82  2020-03-22   53578            5018         3631   24926
# 83  2020-03-23   59138            5683         4204   28572
# 84  2020-03-24   63927            6650         4749   33089
# 85  2020-03-25   69176            8077         5560   39673
# 86  2020-03-26   74386            9529         6412   47610
# 87  2020-03-27   80539           11658         7431   56188
# 88  2020-03-28   86498           14543         8603   64059
# 89  2020-03-29   92472           17089         9762   72248
# 90  2020-03-30   97689           19522        10866   78797
# 91  2020-03-31  101739           22141        11750   85195
# 92  2020-04-01  105792           25150        12595   94417
# 93  2020-04-02  110574           29474        13614  102136
# 94  2020-04-03  115242           33718        14697  110238
# 95  2020-04-04  119827           38168        15723  117710
# 96  2020-04-05  124632           41903        16627  124736
# 97  2020-04-06  128948           47806        17851  130759
# 98  2020-04-07  132547           51608        18803  135032
# 99  2020-04-08  135586           55242        19580  140510
# 100 2020-04-09  139422           60733        20549  146690
# 101 2020-04-10  143626           65077        21762  152446
# 102 2020-04-11  147577           70272        23097  157022>

# %%
import datetime

plt.rcParams.update({'font.size': 16})
plt.rcParams['axes.facecolor'] = 'whitesmoke'

ax = all_data.plot(figsize=(20,10), x='date', color=('b','r','orange','g'))


plt.axvline(x= datetime.datetime(2020, 3, 9, 0, 0), color = 'b')  # IT lockdown
plt.axvline(x= datetime.datetime(2020, 3, 21, 0, 0), color = 'r') # UK lockdown
plt.axvline(x= datetime.datetime(2020, 3, 16, 0, 0), color = 'orange') # NL lockdown
plt.axvline(x= datetime.datetime(2020, 3, 14, 0, 0), color = 'g') # ES lockdown
plt.legend()

left, width = .05, .5
bottom, height = .70, .5
right = left + width
top = bottom + height

#ax.xaxis.set_major_locator(MultipleLocator(1))


ax.text(.22, .70, 'Italy Lockdown',
        horizontalalignment='left',
        verticalalignment='bottom',
        transform=ax.transAxes)

ax.text(.60, .60, 'NL Lockdown',
        horizontalalignment='left',
        verticalalignment='bottom',
        transform=ax.transAxes)

ax.text(.67, .80, 'UK Lockdown',
        horizontalalignment='left',
        verticalalignment='bottom',
        transform=ax.transAxes)

ax.text(.41, .80, 'ES Lockdown',
        horizontalalignment='left',
        verticalalignment='bottom',
        transform=ax.transAxes)

plt.show()
