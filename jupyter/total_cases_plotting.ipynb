# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
filename = '../data/csv/total_cases.csv'
df = pd.read_csv(filename)

# %%
d_from = '2020-03-01'
d_to = '2020-04-15'

df = df[(df['date'] >= d_from) & (df['date'] <= d_to)]
df['date'] = pd.to_datetime(df['date'])

# %%
all_data = df[['date', 'Italy', 'United Kingdom', 'Netherlands', 'Spain']]
all_data.head
# Out:
# <bound method NDFrame.head of          date    Italy  United Kingdom  Netherlands   Spain
# 40 2020-03-01   1128.0            23.0          7.0    45.0
# 41 2020-03-02   1689.0            36.0         13.0    45.0
# 42 2020-03-03   2036.0            39.0         18.0   114.0
# 43 2020-03-04   2502.0            51.0         28.0   151.0
# 44 2020-03-05   3089.0            89.0         38.0   198.0
# 45 2020-03-06   3858.0           118.0         82.0   257.0
# 46 2020-03-07   4636.0           167.0        128.0   374.0
# 47 2020-03-08   5883.0           210.0        188.0   430.0
# 48 2020-03-09   7375.0           277.0        265.0   589.0
# 49 2020-03-10   9172.0           323.0        321.0  1024.0
# 50 2020-03-11  10149.0           373.0        382.0  1639.0
# 51 2020-03-12  12462.0           460.0        503.0  2140.0
# 52 2020-03-13  15113.0           594.0        614.0  2965.0
# 53 2020-03-14  17660.0           802.0        804.0  4231.0
# 54 2020-03-15  21157.0          1144.0        959.0  5753.0
# 55 2020-03-16  24747.0          1395.0       1135.0  7753.0
# 56 2020-03-17  27980.0          1547.0       1413.0  9191.0>

# %%
import datetime

plt.rcParams.update({'font.size': 16})
plt.rcParams['axes.facecolor'] = 'whitesmoke'

ax = all_data.plot(figsize=(20,10), x='date', color=('b','r','orange','g'))


plt.axvline(x= datetime.datetime(2020, 3, 9, 0, 0), color = 'b')  # IT lockdown
plt.axvline(x= datetime.datetime(2020, 3, 21, 0, 0), color = 'r') # UK lockdown
plt.axvline(x= datetime.datetime(2020, 3, 16, 0, 0), color = 'orange') # NL lockdown
plt.axvline(x= datetime.datetime(2020, 3, 14, 0, 0), color = 'g') # ES lockdown
plt.legend()

left, width = .05, .5
bottom, height = .70, .5
right = left + width
top = bottom + height

#ax.xaxis.set_major_locator(MultipleLocator(1))


ax.text(.22, .70, 'Italy Lockdown',
        horizontalalignment='left',
        verticalalignment='bottom',
        transform=ax.transAxes)

ax.text(.60, .60, 'NL Lockdown',
        horizontalalignment='left',
        verticalalignment='bottom',
        transform=ax.transAxes)

ax.text(.67, .80, 'UK Lockdown',
        horizontalalignment='left',
        verticalalignment='bottom',
        transform=ax.transAxes)

ax.text(.41, .80, 'ES Lockdown',
        horizontalalignment='left',
        verticalalignment='bottom',
        transform=ax.transAxes)

plt.show()
