# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
excel_file = '../data/WHO-2.xlsx'
data = pd.read_excel(excel_file)

# %%
data.head()
# Out:
#         Date Country  Total confirmed  Total new  Total deaths  \
# 0 2020-03-09   Italy             7375       1492           366
# 1 2020-03-08   Italy             5883       1247           234
# 2 2020-03-07   Italy             4636        778           197
# 3 2020-03-09      UK              277         67             2
# 4 2020-03-10   Italy             9172       1797           463
#
#    Total new deaths
# 0               132
# 1                37
# 2                49
# 3                 0
# 4                97

# %%
data_by_country_by_day = data.pivot_table(index=['Country','Date'])
data_by_country_by_day.head()
# Out:
#                     Total confirmed  Total deaths  Total new  Total new deaths
# Country Date
# France  2020-03-04              212             4         21                 1
#         2020-03-05              282             4         73                 0
#         2020-03-06              420             6        138                 2
#         2020-03-07              613             9        193                 3
#         2020-03-08              706            10         93                 1

# %%
data_by_country_by_day = data.pivot_table(index=['Country','Date'], values=['Total confirmed'])
data_by_country_by_day.head()
# Out:
#                     Total confirmed
# Country Date
# France  2020-03-04              212
#         2020-03-05              282
#         2020-03-06              420
#         2020-03-07              613
#         2020-03-08              706

# %%
it_data = data[data['Country']=='Italy'].rename(columns={"Total confirmed": "Italy Total confirmed"})
it_data_by_day = it_data.pivot_table(index=['Date'], values=['Italy Total confirmed'])
it_data_by_day.head()
# Out:
#             Italy Total confirmed
# Date
# 2020-03-04                   2502
# 2020-03-05                   3089
# 2020-03-06                   3858
# 2020-03-07                   4636
# 2020-03-08                   5883

# %%
uk_data = data[data['Country']=='UK'].rename(columns={"Total confirmed": "UK Total confirmed"})
uk_data_by_day = uk_data.pivot_table(index=['Date'], values=['UK Total confirmed'])
uk_data_by_day.head()
# Out:
#             UK Total confirmed
# Date
# 2020-03-04                  51
# 2020-03-05                  89
# 2020-03-06                 118
# 2020-03-07                 167
# 2020-03-08                 210

# %%
nl_data = data[data['Country']=='NL'].rename(columns={"Total confirmed": "NL Total confirmed"})
nl_data_by_day = nl_data.pivot_table(index=['Date'], values=['NL Total confirmed'])
nl_data_by_day.head()
# Out:
#             NL Total confirmed
# Date
# 2020-03-04                  28
# 2020-03-05                  38
# 2020-03-06                  82
# 2020-03-07                 128
# 2020-03-08                 188

# %%
fr_data = data[data['Country']=='France'].rename(columns={"Total confirmed": "France Total confirmed"})
fr_data_by_day = fr_data.pivot_table(index=['Date'], values=['France Total confirmed'])
fr_data_by_day.head()
# Out:
#             France Total confirmed
# Date
# 2020-03-04                     212
# 2020-03-05                     282
# 2020-03-06                     420
# 2020-03-07                     613
# 2020-03-08                     706

# %%
ax = it_data_by_day.plot()
uk_data_by_day.plot(ax=ax)
nl_data_by_day.plot(ax=ax)
fr_data_by_day.plot(ax=ax)
plt.show()
